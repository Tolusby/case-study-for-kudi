# %% [markdown]
# ## Case Study for Kudi Interview Questions
#
# Kindly note that data frame for answer 2 used here were abstractly created by me for the purpose of these excercise.
#
# Data for Rainfall in Glassglow was downloaded from Urban Big Data Center [link](http://ubdc.gla.ac.uk/dataset/glasgow-bishopton-general-weather-station-data-1959-2013)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Country and debt .csv')

# %%
# This shows the first 4 rows in the data
df.head()
# Out:
#    year  Country  Household dedt per capital
# 0  1960       US            $419,790,588.00
# 1  1961  Germary            $411,898,965.00
# 2  1962       UK            $404,024,433.00
# 3  1963       UK            $396,028,278.00
# 4  1964    Brazil           $387,907,748.00

# %%
# This shows the last 4 rows in the data 

df.tail()
# Out:
#      year        Country  Household dedt per capital
# 880  1967        Germary            $801,349,486.00
# 881  1968             UK            $791,500,756.00
# 882  1969             UK            $781,558,432.00
# 883  1970          Brazil           $771,546,780.00
# 884  1971  United Kingdom           $760,193,906.00

# %%
# This shows different statistical data such as mean, variance e.t.c for the year

df.describe()
# Out:
#               year
# count   885.000000
# mean   1987.840678
# std      17.182957
# min    1960.000000
# 25%    1973.000000
# 50%    1987.000000
# 75%    2003.000000
# max    2018.000000

# %% [markdown]
# ##  2. Countries and Debt
#
# The map below shows the debt of each coutry with the use of Tableau Public
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# As seen above it willl be preferable to create a map with all the countries in order to visualize the data

# %% [markdown]
# Horizontal Bars will also help to create better understanding of the relationship betwenn the debt of each countries
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 3. Weather Forecast in Glasglow UK

# %% [markdown]
# The bar chat below shows the relationship between Humdity , Rain Fall & Sun on April 10th
#
# ![image.png](attachment:image.png)
